# %%
import numpy as np


x = np.linspace(0, 2*np.pi, 200)
np.cosh(x)
# Out:
# array([  1.        ,   1.00049849,   1.00199447,   1.00448943,
#          1.00798584,   1.01248721,   1.01799801,   1.02452375,
#          1.03207092,   1.04064705,   1.0502607 ,   1.06092144,
#          1.07263991,   1.08542778,   1.09929782,   1.11426384,
#          1.13034076,   1.14754463,   1.16589258,   1.1854029 ,
#          1.20609507,   1.22798969,   1.2511086 ,   1.27547486,
#          1.30111274,   1.32804782,   1.35630694,   1.38591829,
#          1.41691138,   1.44931711,   1.48316779,   1.51849718,
#          1.55534048,   1.59373444,   1.63371733,   1.67532902,
#          1.71861099,   1.7636064 ,   1.81036009,   1.8589187 ,
#          1.90933062,   1.96164612,   2.01591736,   2.07219844,
#          2.13054547,   2.19101664,   2.25367222,   2.31857468,
#          2.38578873,   2.45538138,   2.52742202,   2.60198247,
#          2.67913706,   2.75896271,   2.84153902,   2.9269483 ,
#          3.01527572,   3.10660932,   3.20104018,   3.29866244,
# ...
